# %% [markdown]
# This is an extended task from the task one exercises. This code is reading a website, and fetching what i can work with as an engineer at this company.

# %%
#What do I need?
#i need some libraries so that i can run openai and call the api to make it summarize the webpage and give me a description of what i can work with as an engineer at this company. its also possible to make it write an application for me as well

# %%
from dotenv import load_dotenv
from openai import OpenAI
